# %%
from datetime import datetime
startTime = datetime.now()

from collections import defaultdict

filepath = 'input.txt'

INSTRUCTION_JUMPS = {'01': 4, '02': 4, '03': 2, '04': 2, '05': 3, '06': 3, '07': 4, '08': 4, '09': 2}
MODES = {'0': lambda i, n, data, relative_base: data[data[i+n]], 
         '1': lambda i, n, data, relative_base: data[i+n],
         '2': lambda i, n, data, relative_base: data[data[i+n] + relative_base]}

inputs = []
def run_program(data):
    global inputs
    data = data + [0] * 1000
    i, num_inputs = 0, 0
    relative_base = 0
    
    while data[i] != 99:
        
        opcode = str(data[i])[-2:].zfill(2)
        mode = str(data[i])[:-2].zfill(3)
        #print(opcode)
        #print(i)
        #print(data[i])
        
        
        if opcode in ('01', '02', '04', '05', '06', '07', '08', '09'):
            p1 = MODES[mode[2]](i, 1, data, relative_base)     
        if opcode in ('01', '02', '05', '06', '07', '08'):
            p2 = MODES[mode[1]](i, 2, data, relative_base)
            
        
        
        if opcode in ['03']:
            if mode[2] == '2':
                p3 = data[i+1] + relative_base
            else:
                p3 = data[i+1]
            data = data + [0] * (p3+1-len(data))                  
            
        if opcode in ['01', '02', '07', '08']:
            if mode[0] == '2':
                p3 = data[i+3] + relative_base
            else:
                p3 = data[i+3]
            data = data + [0] * (p3+1-len(data))

        if opcode == '01':
            data[p3] = p1 + p2
        elif opcode == '02':
            data[p3] = p1 * p2
        elif opcode == '03':
            #print('taking input')
            
            
            #data[p3] = inputs[-1]
            #inputs = []
            
            
            #print(data[p3]) 
            data[p3] = inputs[num_inputs]
            #print(inputs[num_inputs])
            #print(inputs[num_inputs])
            num_inputs += 1
        elif opcode == '04':
            #print('yielding', p1)
            yield p1 
        elif opcode == '05' and p1 != 0:
            i = p2
            continue
        elif opcode == '06' and p1 == 0:
            i = p2
            continue 
        elif opcode == '07':
            data[p3] = int(p1 < p2) 
        elif opcode == '08':
            data[p3] = int(p1 == p2)
        elif opcode == '09':
            relative_base += p1
        else:
            pass
            
        i += INSTRUCTION_JUMPS[opcode]
        
    yield None
    
    
ADJACENTS = {1:(0, 1), 2: (0, -1), 3: (-1, 0), 4: (1, 0)}

global inputs

opposite = {1:2, 2:1, 3:4, 4:3}

with open(filepath, 'r') as f:
    for line in f.readlines():
        data = [int(i) for i in line.strip().split(',')]
f.close()
#print(data)

grid = []
affected = 0
import numpy
size = 50
#grid = numpy.zeros((size, size))

for y in range(size):
    grid.append('')
    num_ones = 0
    caught_beam = False
    for x in range(size):
        inputs = [x, y]
        program = run_program(data[:])
        #inputs.append(x)
        #inputs.append(y)
        pos = next(program)
        affected += pos
        #print(pos)
        
        grid[y] = grid[y] + str(pos)
        num_ones += pos
        
        if pos == 1:
            caught_beam = True
            
        if caught_beam and pos == 0:
            #print('breaking x at line', x)
            break
        #print(grid[y][x])
        
    if num_ones == 0 and y != 1:
        print('breaking y at line', y)
        break
    if y % 100 == 0:
        print(size - y)

print(affected)
for n, line in enumerate(grid):
    print(n, line)
#for n, line in enumerate(grid):
#    print(n, ''.join(['#' if i == 1 else ' ' for i in line]))
# BFS until a bot hits oxygen supply
# reset path length and set of already explored tiles
# use same bot still parked at oxygen to BFS until ran out of spaces to explore
# Out:
# 50
# breaking y at line 24
# 152
# 0 10
# 1 00000000000000000000000000000000000000000000000000
# 2 0000010
# 3 0000000110
# 4 0000000001110
# 5 0000000000011110
# 6 0000000000000111110
# 7 000000000000000111110
# 8 000000000000000001111110
# 9 000000000000000000011111110
# 10 000000000000000000000011111110
# 11 000000000000000000000000111111110
# 12 000000000000000000000000001111111110
# 13 000000000000000000000000000011111111110
# 14 00000000000000000000000000000011111111110
# 15 00000000000000000000000000000000111111111110
# 16 00000000000000000000000000000000001111111111110
# 17 00000000000000000000000000000000000011111111111110
# 18 00000000000000000000000000000000000000111111111111
# 19 00000000000000000000000000000000000000001111111111
# 20 00000000000000000000000000000000000000000001111111
# 21 00000000000000000000000000000000000000000000011111
# 22 00000000000000000000000000000000000000000000000111
# 23 00000000000000000000000000000000000000000000000001
# 24 00000000000000000000000000000000000000000000000000

# %%
from datetime import datetime
startTime = datetime.now()

from collections import defaultdict

filepath = 'input.txt'

INSTRUCTION_JUMPS = {'01': 4, '02': 4, '03': 2, '04': 2, '05': 3, '06': 3, '07': 4, '08': 4, '09': 2}
MODES = {'0': lambda i, n, data, relative_base: data[data[i+n]], 
         '1': lambda i, n, data, relative_base: data[i+n],
         '2': lambda i, n, data, relative_base: data[data[i+n] + relative_base]}

inputs = []
def run_program(data):
    global inputs
    data = data + [0] * 1000
    i, num_inputs = 0, 0
    relative_base = 0
    
    while data[i] != 99:
        
        opcode = str(data[i])[-2:].zfill(2)
        mode = str(data[i])[:-2].zfill(3)
        #print(opcode)
        #print(i)
        #print(data[i])
        
        
        if opcode in ('01', '02', '04', '05', '06', '07', '08', '09'):
            p1 = MODES[mode[2]](i, 1, data, relative_base)     
        if opcode in ('01', '02', '05', '06', '07', '08'):
            p2 = MODES[mode[1]](i, 2, data, relative_base)
            
        
        
        if opcode in ['03']:
            if mode[2] == '2':
                p3 = data[i+1] + relative_base
            else:
                p3 = data[i+1]
            data = data + [0] * (p3+1-len(data))                  
            
        if opcode in ['01', '02', '07', '08']:
            if mode[0] == '2':
                p3 = data[i+3] + relative_base
            else:
                p3 = data[i+3]
            data = data + [0] * (p3+1-len(data))

        if opcode == '01':
            data[p3] = p1 + p2
        elif opcode == '02':
            data[p3] = p1 * p2
        elif opcode == '03':
            #print('taking input')
            
            
            #data[p3] = inputs[-1]
            #inputs = []
            
            
            #print(data[p3]) 
            data[p3] = inputs[num_inputs]
            #print(inputs[num_inputs])
            #print(inputs[num_inputs])
            num_inputs += 1
        elif opcode == '04':
            #print('yielding', p1)
            yield p1 
        elif opcode == '05' and p1 != 0:
            i = p2
            continue
        elif opcode == '06' and p1 == 0:
            i = p2
            continue 
        elif opcode == '07':
            data[p3] = int(p1 < p2) 
        elif opcode == '08':
            data[p3] = int(p1 == p2)
        elif opcode == '09':
            relative_base += p1
        else:
            pass
            
        i += INSTRUCTION_JUMPS[opcode]
        
    yield None
    
    
ADJACENTS = {1:(0, 1), 2: (0, -1), 3: (-1, 0), 4: (1, 0)}

global inputs

opposite = {1:2, 2:1, 3:4, 4:3}

with open(filepath, 'r') as f:
    for line in f.readlines():
        data = [int(i) for i in line.strip().split(',')]
f.close()
#print(data)

grid = []
affected = 0
import numpy
size = 10000
#grid = numpy.zeros((size, size))

last_x_left, last_x_right = 0, 0
for y in range(size):
    
    grid.append('')
    num_ones = 0
    caught_beam = False
    
    if y == 1:
        grid[y] = '0' * 5
        #last_x_right = 5
        continue
    
    grid[y] = '0' * last_x_left
    #print('grid before',grid[y] )
    for x in range(last_x_left, size):
        inputs = [x, y]
        program = run_program(data[:])
        pos = next(program)
        
        #grid[y] = grid[y] + str(pos)
        num_ones += pos
        
        if pos == 1:
            grid[y] = grid[y] + '0' * (x - last_x_left)
            last_x_left = x
            caught_beam = True
            break
            
    #print('grid middle',grid[y] )
    if last_x_left > last_x_right:
        last_x_right = last_x_left + 1
            
    for x in range(last_x_right, size):
        inputs = [x, y]
        program = run_program(data[:])
        pos = next(program)
        #print(x, y, pos)
        if pos == 0:
            last_x_right = x
            break
            
    grid[y] = grid[y] + '1' * (last_x_right - last_x_left) + '0'
    #print('grid after',grid[y] )
    #print()
    if num_ones == 0 and y != 1:
        print('breaking y at line', y)
        break
    if y % 100 == 0:
        print(size - y)

for n, line in enumerate(grid):
    bottom_left_x = line.find('1')
    bottom_left_y = n
    
    square = 100
    
    top_left_y = n - square + 1
    top_left_x = bottom_left_x + square - 1
    
    #print(n)
    #print(bottom_left_y, bottom_left_x)
    #print(top_left_y, top_left_x)
    #print()
    
    if top_left_y > 0 and top_left_x < len(grid[top_left_y]) and grid[top_left_y][top_left_x] == '1':
        #print('catch', n)
        if grid[top_left_y][top_left_x+1] == '0':
            print(bottom_left_x, top_left_y)
            print('ans', bottom_left_x*10000 + top_left_y)
            break
        
    
print('done')

'''
0 10
1 00000000000000000000000000000000000000000000000000
2 0000010
3 0000000110
4 0000000001110
5 0000000000011110
6 0000000000000111110
'''
# Out:
# 10000
# 9900
# 9800
# 9700
# 9600
# 9500
# 9400
# 9300
# 9200
# 9100
# 9000
# 8900
# 8800
# 8700
# 8600
# 8500
# 8400
# 8300
# 8200
# 8100
# 8000
# 7900
# 7800
# 7700
# 7600
# 7500
# 7400
# 7300
# 7200
# 7100
# 7000
# 6900
# 6800
# 6700
# 6600
# 6500
# 6400
# 6300
# 6200
# 6100
# 6000
# 5900
# 5800
# 5700
# 5600
# 5500
# 5400
# 5300
# breaking y at line 4755
# 1073 411
# ans 10730411
# done
# '\n0 10\n1 00000000000000000000000000000000000000000000000000\n2 0000010\n3 0000000110\n4 0000000001110\n5 0000000000011110\n6 0000000000000111110\n'

# %%
from datetime import datetime
startTime = datetime.now()

import numpy

filepath = 'input.txt'
filepath = 'test.txt'

DIRECTIONS = {'U': (0, 1), 'D': (0, -1), 'L': (-1, 0), 'R':(1, 0)}


def p1(path1, path2):
    
    grid = numpy.zeros((10000, 10000))
    middle = 10000//2
    cur_x, cur_y = middle, middle
    
    for i in path1:
        d, l = i[:1], i[1:]
        print(d, l)
        
        for j in l:
            
    
    
    print(middle)
    return 1
        
if __name__ == '__main__':
    data = []
    with open(filepath, 'r') as f:
        for line in f.readlines():
            data.append(line.strip().split(','))
    f.close()
    
    path1 = data[0]
    path2 = data[1]
    
    print(p1(path1, path2))
    print(str(datetime.now() - startTime)[:-3])
    
    '''
    2890696
    8226
    0:00:00.067
    '''
# Out:
# R dasda 8
# U dasda 5
# L dasda 5
# D dasda 3
# 5000
# 1
# 0:00:00.001

# %%
from datetime import datetime
startTime = datetime.now()

import numpy

filepath = 'input.txt'
#filepath = 'test.txt'

DIRECTIONS = {'U': (0, 1), 'D': (0, -1), 'L': (-1, 0), 'R':(1, 0)}


path1_positions = set()
def p1(path1, path2):
    
    cur_x, cur_y = 0, 0
    
    for i in path1:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            path1_positions.add((cur_x, cur_y))
    #print(path1_positions)
    matches = set()
    cur_x, cur_y = 0, 0
    for i in path2:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            if (cur_x, cur_y) in path1_positions:
                matches.add((cur_x, cur_y))
                #print((cur_x, cur_y))
    #print(path1_positions)
    
    lowest = 9999999
    for i in matches:
        #print(list(i))
        
        
        if sum([abs(a) for a in i]) < lowest:
            lowest = sum([abs(a) for a in i])
        
    
    
    return lowest
        
if __name__ == '__main__':
    data = []
    with open(filepath, 'r') as f:
        for line in f.readlines():
            data.append(line.strip().split(','))
    f.close()
    
    path1 = data[0]
    path2 = data[1]
    
    print(p1(path1, path2))
    print(str(datetime.now() - startTime)[:-3])
    
    '''
    2890696
    8226
    0:00:00.067
    '''
# Out:
# 1017
# 0:00:00.101

# %%
print(abs(-2))
# Out:
# 2

# %%
from datetime import datetime
startTime = datetime.now()

import numpy

filepath = 'input.txt'
#filepath = 'test.txt'

DIRECTIONS = {'U': (0, 1), 'D': (0, -1), 'L': (-1, 0), 'R':(1, 0)}


path1_positions = []
def p1(path1, path2):
    
    cur_x, cur_y = 0, 0
    steps = 0
    p1_steps = []
    for i in path1:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            steps += 1
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            path1_positions.append((cur_x, cur_y))
            p1_steps.append(steps)
    #print(path1_positions)
    matches = set()
    cur_x, cur_y = 0, 0
    steps = 0
    for i in path2:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            steps += 1
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            if (cur_x, cur_y) in path1_positions:
                matches.add((steps, p1_steps[path1_positions.index((cur_x, cur_y))]    ))
                #print((cur_x, cur_y))
    #print(path1_positions)
    
    print('summing')
    
    lowest = 9999999
    for i in matches:
        print(list(i))
        
        if sum([abs(a) for a in i]) < lowest:
            lowest = sum([abs(a) for a in i])
        
    
    
    return lowest
        
if __name__ == '__main__':
    data = []
    with open(filepath, 'r') as f:
        for line in f.readlines():
            data.append(line.strip().split(','))
    f.close()
    
    path1 = data[0]
    path2 = data[1]
    
    print(p1(path1, path2))
    print(str(datetime.now() - startTime)[:-3])
    
    '''
    2890696
    8226
    0:00:00.067
    '''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-5b274db78981> in <module>()
#      66     path2 = data[1]
#      67
# ---> 68     print(p1(path1, path2))
#      69     print(str(datetime.now() - startTime)[:-3])
#      70
#
# <ipython-input-50-5b274db78981> in p1(path1, path2)
#      38             cur_x = cur_x + DIRECTIONS[d][0]
#      39             cur_y = cur_y + DIRECTIONS[d][1]
# ---> 40             if (cur_x, cur_y) in path1_positions:
#      41                 matches.add((steps, p1_steps[path1_positions.index((cur_x, cur_y))]    ))
#      42                 #print((cur_x, cur_y))
#
# KeyboardInterrupt:

# %%
a = set()
a.add((1,1,1))
a.add((2,3,1))
a.add((5,5,1))
print(a)

print([x[:2] for x in list(a)])
# Out:
# {(1, 1, 1), (5, 5, 1), (2, 3, 1)}
# [(1, 1), (5, 5), (2, 3)]

# %%
from datetime import datetime
startTime = datetime.now()

import numpy

filepath = 'input.txt'
filepath = 'test.txt'

DIRECTIONS = {'U': (0, 1), 'D': (0, -1), 'L': (-1, 0), 'R':(1, 0)}


path1_positions = set()
def p1(path1, path2):
    
    cur_x, cur_y = 0, 0
    steps = 0
    p1_steps = []
    for i in path1:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            steps += 1
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            path1_positions.add((cur_x, cur_y, steps))
    #print(path1_positions)
    matches = set()
    cur_x, cur_y = 0, 0
    steps = 0
    repeats = [x[:2] for x in list(path1_positions)]
    for i in path2:
        d, l = i[:1], int(i[1:])
        #print(d, l)
        
        for j in range(1, l+1):
            steps += 1
            cur_x = cur_x + DIRECTIONS[d][0]
            cur_y = cur_y + DIRECTIONS[d][1]
            if (cur_x, cur_y) in repeats:
                for x in list(path1_positions):
                    if (x[0], x[1])  == (cur_x, cur_y):
                        a = x[2]
                        print(a)
                
                
                matches.add((steps, a[2]))
                #print((cur_x, cur_y))
    #print(path1_positions)
    
    print('summing')
    
    lowest = 9999999
    for i in matches:
        print(list(i))
        
        if sum([abs(a) for a in i]) < lowest:
            lowest = sum([abs(a) for a in i])
        
    
    
    return lowest
        
if __name__ == '__main__':
    data = []
    with open(filepath, 'r') as f:
        for line in f.readlines():
            data.append(line.strip().split(','))
    f.close()
    
    path1 = data[0]
    path2 = data[1]
    
    print(p1(path1, path2))
    print(str(datetime.now() - startTime)[:-3])
    
    '''
    2890696
    8226
    0:00:00.067
    '''
# Out:
# 404
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-eb4ab174a7a1> in <module>()
#      72     path2 = data[1]
#      73
# ---> 74     print(p1(path1, path2))
#      75     print(str(datetime.now() - startTime)[:-3])
#      76
#
# <ipython-input-57-eb4ab174a7a1> in p1(path1, path2)
#      45
#      46
# ---> 47                 matches.add((steps, a[2]))
#      48                 #print((cur_x, cur_y))
#      49     #print(path1_positions)
#
# TypeError: 'int' object is not subscriptable

# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
#filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = [int(line.strip()) for line in f.readlines()]

volt = 0
    
max_volt = max(data) + 3
diffs = dict()
    
while volt < max_volt - 3:
    valid = [volt + i for i in range(1, 4)]
    
    for n, i in enumerate(valid):

            
        if i in data:
            if n+1 not in diffs.keys():
                diffs[n+1] = 1
            else:
                diffs[n+1] += 1
            
            data.remove(i)
            volt = i
            break
            
    
            
    print(valid, volt, diffs)
        
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942

# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = [int(line.strip()) for line in f.readlines()]

volt = 0
configs = 0
max_volt = max(data) + 3
volt = 0

# some sort of tertiary tree where each node is a point on the adapter
# how to predict without having to hit each end node?

r = 0
def find(volt, new_data):
    valid = [volt + i for i in range(1, 4) if volt + i in new_data]
    #print('vaid', valid)
    for n, i in enumerate(valid):
        #print(n, i)
        new_data.remove(i)
        volt = i
        #print(i)
        if volt == max_volt - 3:
            global configs
            configs += 1
        else:
            find(volt, new_data[:])
            
find(volt, data)         

print('configs', configs)
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942

# %%
print(sorted(data))

# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
#filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = (int(line.strip()) for line in f.readlines())
data.append(0)
data = sorted(data)
print(data)
configs = 0
max_volt = max(data) + 3
n = 0
# some sort of tertiary tree where each node is a point on the adapter
# how to predict without having to hit each end node?
r = 0
def find(n, v):
    #print(n, data[n])
    if data[n+1] >= data[n] + 4:
        print('hit')
        return v
    
    for i in (1,2,3):
        if data[n]+i in data:
            #print('found', data[n]+i, i)
            if data[n]+i == max_volt - 3:
                return v + 1
            else:
                v = find(data.index(data[n] + i), v)
    
    return v


        
print(find(0, 0))

print('configs', configs)
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942

# %%
print(list(range(1, 4)))
# Out:
# [1, 2, 3]

# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
#filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = {int(line.strip()) for line in f.readlines()}
volt = 0
configs = 0
max_volt = max(data) + 3
volt = 0

# some sort of tertiary tree where each node is a point on the adapter
# how to predict without having to hit each end node?

r = 0
def find(volt, v):
    for i in (1, 2, 3):
        if volt + i in data:
            if volt + i == max_volt - 3:
                return v + 1
            else:
                v = find(volt+i, v)
                
    if v % 1000000 == 0:
        print(v)
    return v
            
print(find(volt, 0))    

print('configs', configs)
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942
# Out:
# 1000000
# 1000000
# 1000000
# 1000000
# 2000000
# 2000000
# 2000000
# 2000000
# 3000000
# 3000000
# 3000000
# 3000000
# 4000000
# 4000000
# 4000000
# 4000000
# 5000000
# 5000000
# 5000000
# 5000000
# 6000000
# 6000000
# 6000000
# 6000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 7000000
# 8000000
# 8000000
# 8000000
# 8000000
# 9000000
# 9000000
# 9000000
# 9000000
# 10000000
# 10000000
# 10000000
# 10000000
# 11000000
# 11000000
# 11000000
# 11000000
# 12000000
# 12000000
# 12000000
# 12000000
# 13000000
# 13000000
# 13000000
# 13000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 14000000
# 15000000
# 15000000
# 15000000
# 15000000
# 16000000
# 16000000
# 16000000
# 16000000
# 17000000
# 17000000
# 17000000
# 17000000
# 18000000
# 18000000
# 18000000
# 18000000
# 19000000
# 19000000
# 19000000
# ...

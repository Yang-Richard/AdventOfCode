# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
#filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = [[i for i in line.strip()] for line in f.readlines()]
    
n = 0 
for i in data:
    print(i)

adjacent = [[-1, -1], [0, -1], [-1, 0], [-1, 1], [1, -1], [1, 0], [0, 1], [1, 1]]

num_change = 0
new_data = [i[:] for i in data]
last = 0
while True:
    num_change = 0
    for y, row in enumerate(data):
        #print('row', y, row)
        for x, pos in enumerate(row):
            #print('pos', pos)
            seats = []
            
            

            for xx, yy in adjacent:
                    
                if 0 <= y + yy < len(data) and 0 <= x + xx < len(row):
                    seats.append(data[y + yy][x + xx])
                    #print(seats)

            empty = seats.count('L')
            occupied = seats.count('#')
            
            #if y == 0 and x == 1:
            #    print('e', empty, 'o', occupied)
                
                
            if pos == 'L' and occupied == 0:
                new_data[y][x] = '#'  
                num_change += 1
            elif pos == '#' and occupied >= 4:
                new_data[y][x] = 'L'  
                num_change += 1
            else:
                pass
            
        #print('\n')
        
    data = [i[:] for i in new_data]
        
        
    
    
    if num_change != last:
        last = num_change
    else:
        print('num change', last)
        counter = 0
        for i in data:
            counter += i.count('#')
        print(counter)
        break
        
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L']
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L']
# ...

# %%
from datetime import datetime
startTime = datetime.now()

from itertools import combinations

filepath = 'input.txt'
#filepath = 'test.txt'

r1, r2 = 0, 0

with open(filepath, 'r') as f:
    data = [[i for i in line.strip()] for line in f.readlines()]
    
n = 0 
for i in data:
    print(i)

adjacent = [[-1, -1], [0, -1], [-1, 0], [-1, 1], [1, -1], [1, 0], [0, 1], [1, 1]]

num_change = 0
new_data = [i[:] for i in data]
last = 0
while True:
    num_change = 0
    for y, row in enumerate(data):
        #print('row', y, row)
        for x, pos in enumerate(row):
            #print('pos', pos)
            
            occupied = 0

            for xx, yy in adjacent:
                a, b = x, y
                while 0 <= b < len(data) and 0 <= a < len(row):
                    a += xx
                    b += yy
                    if 0 <= b < len(data) and 0 <= a < len(row) and data[b][a] == '#':
                        #print('hit')
                        occupied += 1
                        break
                    elif 0 <= b < len(data) and 0 <= a < len(row) and data[b][a] == 'L':
                        break
                        
                    #print(a, b, data[b][a])
                        
            #if y == 0 and x == 1:
            #    print('e', empty, 'o', occupied)
            #print(y, x, occupied)
                
            if pos == 'L' and occupied == 0:
                #print('change to #')
                new_data[y][x] = '#'  
                num_change += 1
            elif pos == '#' and occupied >= 5:
                new_data[y][x] = 'L'  
                num_change += 1
            else:
                pass
            
            #break
        #break
        #print('\n')
    data = [i[:] for i in new_data]

        
    
    
    if num_change != last:
        last = num_change
    else:
        print('num change', last)
        counter = 0
        for i in data:
            counter += i.count('#')
        print(counter)
        break
        
print(r1, r2)
print(str(datetime.now() - startTime)[:-3]) # 25918798 3340942
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L']
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L']
# ...
